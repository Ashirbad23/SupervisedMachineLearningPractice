# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
digits = load_digits()
X = digits.data
Y = digits.target

X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
pca_model = PCA(n_components=2)
New_x = pca_model.fit_transform(X)
New_x
# Out:
# array([[ -1.25946721,  21.2748862 ],
#        [  7.95761308, -20.76870661],
#        [  6.99192271,  -9.95598458],
#        ...,
#        [ 10.80128155,  -6.96024337],
#        [ -4.87209964,  12.42395117],
#        [ -0.34439268,   6.36556204]])

# %%
plt.scatter(New_x[:, 0], New_x[:, 1], c=Y)
plt.xlabel("First PCA components")
plt.ylabel("Second PCA components")
plt.colorbar()
plt.tight_layout()
